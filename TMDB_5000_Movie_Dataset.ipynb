# %% [markdown]
# ## TMDB 5000 Movie Dataset
# ### In order to solve this set of questions you need first to download This [Dataset](https://www.kaggle.com/tmdb/tmdb-movie-metadata?select=tmdb_5000_movies.csv)
# #### and then follow the comments in each cell
#
# ### Objectives
# - DataFrames

# %%
### Open Your CSV file and print the first 10 rows in a good format ###
import pandas as pd
movies = pd.read_csv('tmdb_5000_movies.csv')
movies.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
### Check if any NANs in your dataset and fill them with a good filer ###
movies.isnull().sum()
movies["homepage"].fillna("No homepage", inplace = True)
movies["overview"].fillna("No overview", inplace = True)
movies["release_date"].fillna((movies["release_date"].mode()[0]), inplace = True)
movies["runtime"].fillna((movies["runtime"].mean()), inplace = True)
movies["tagline"].fillna("No tagline", inplace = True)
movies.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
### Discover the types of each columns and modify them if needed ###
movies.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
### Give a very simple statistical analsys for the numerical columns ###
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4803.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.607225
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   117.500000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
### Calculate the mean rate for [1999, 1980, 2004, 2017] the movies grouped by years ###

### Ex: Average Movies Rate at 2009 is 6.065587 ###
l = []
movies['year'] = pd.DatetimeIndex(movies['release_date']).year
grouped_movies = movies.groupby('year')
grouped_movies_mean = grouped_movies['vote_average'].mean()
print('Average Movies Rate at 1999 is:',grouped_movies_mean.loc[1999])
print('Average Movies Rate at 1980 is:',grouped_movies_mean.loc[1980])
print('Average Movies Rate at 2004 is:',grouped_movies_mean.loc[2004])
print('Average Movies Rate at 2017 is:',grouped_movies_mean.loc[2017])
# Out:
# Average Movies Rate at 1999 is: 6.110526315789473
# Average Movies Rate at 1980 is: 6.609090909090909
# Average Movies Rate at 2004 is: 6.10441176470588
# Average Movies Rate at 2017 is: 7.4

# %%
### Rearange the dataframe based on revenue - budget values ###
movies["earnings"] = movies["revenue"] - movies["budget"]
movies.sort_values(by="earnings", ascending=False, inplace=True)
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...         ...                                                ...
# 1652  100000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 141   150000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 338   145000000  [{"id": 37, "name": "Western"}, {"id": 36, "na...
# 135   150000000  [{"id": 18, "name": "Drama"}, {"id": 27, "name...
# 13    255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
### Allocate the year with the largest movies released in ['Action', 'Romance'] ###
import ast
def convert(obj):
    lst = []
    for i in ast.literal_eval(obj):
        lst.append(i['name'])
    return lst

movies['genres'] = movies['genres'].apply(convert)
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(' ', '') for i in x])
movies[movies.genres == "['Action','Romance']"]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count, year, earnings]
# Index: []
#
# [0 rows x 22 columns]

# %%
### Find the movies with top 5 revenue - budget value ###
movies.head()
# Out:
#        budget                                         genres  \
# 0   237000000   [Action, Adventure, Fantasy, ScienceFiction]
# 25  200000000                     [Drama, Romance, Thriller]
# 28  150000000  [Action, Adventure, ScienceFiction, Thriller]
# 44  190000000                                       [Action]
# 16  220000000            [ScienceFiction, Action, Adventure]
#
#                              homepage      id  \
# 0         http://www.avatarmovie.com/   19995
# 25        http://www.titanicmovie.com     597
# 28      http://www.jurassicworld.com/  135397
# 44           http://www.furious7.com/  168259
# 16  http://marvel.com/avengers_movie/   24428
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 28  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# ...

# %%
### Find the year with the highest number of movies release ###
high = movies['year'].value_counts()
high
print(high.index[0])
# Out:
# 2009

# %%
### Find the top 2 countries with the highest production movies number ###
def convert2(obj):
    lst = []
    for i in ast.literal_eval(obj):
        lst.append(i['iso_3166_1'])
    return lst

movies['production_countries'] = movies['production_countries'].apply(convert2)

country = movies['production_countries'].value_counts()
print(country.index[0], country.index[1])
# Out:
# ['US'] ['GB', 'US']

# %%
### Find the top 1 company with the highest production movies number ###
movies['production_companies'] = movies['production_companies'].apply(convert)
com = movies['production_companies'].value_counts()
print(com.index[1])
#movies['production_companies']
# Out:
# ['Paramount Pictures']

# %%
### Find the top 5 movies with the highest rate, and find if there anything common between them. ###
movies.sort_values(by="vote_average", ascending=False, inplace=False).head(5)
# Out:
#       budget                    genres     homepage      id  \
# 4247       1  [Romance, Comedy, Drama]  No homepage  361505
# 4662       0                  [Comedy]  No homepage   40963
# 4045       0   [Comedy, Drama, Family]  No homepage   78373
# 3519       0                  [Comedy]  No homepage   89861
# 3992       0                        []  No homepage  346081
#
#                                                keywords original_language  \
# 4247                                                 []                en
# 4662        [{"id": 10183, "name": "independent film"}]                en
# 4045  [{"id": 1415, "name": "small town"}, {"id": 15...                en
# 3519  [{"id": 131, "name": "italy"}, {"id": 8250, "n...                en
# 3992                                                 []                en
#
#              original_title  \
# 4247  Me You and Five Bucks
# 4662         Little Big Top
# 4045  Dancer, Texas Pop. 81
# 3519       Stiff Upper Lips
# ...

# %%
### Find the most unsuccessful movie along time in terms of revenue - budget ###
movies.tail(1)
# Out:
#        budget                        genres  \
# 13  255000000  [Action, Adventure, Western]
#
#                                  homepage     id  \
# 13  http://disney.go.com/the-lone-ranger/  57201
#
#                                              keywords original_language  \
# 13  [{"id": 1556, "name": "texas"}, {"id": 2673, "...                en
#
#      original_title                                           overview  \
# 13  The Lone Ranger  The Texas Rangers chase down a gang of outlaws...
#
#     popularity                               production_companies  ...  \
# 13   49.046956  [Walt Disney Pictures, Jerry Bruckheimer Films...  ...
#
#      revenue runtime                          spoken_languages    status  \
# 13  89289910   149.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                     tagline            title vote_average vote_count  year  \
# 13  Never Take Off the Mask  The Lone Ranger          5.9       2311  2013
#
#      earnings
# ...

# %%
### Rearange the dataframe based on vote_average column values ###
movies.sort_values(by="vote_average", ascending=False, inplace=True)
movies
# Out:
#       budget                    genres                         homepage  \
# 4247       1  [Romance, Comedy, Drama]                      No homepage
# 4662       0                  [Comedy]                      No homepage
# 4045       0   [Comedy, Drama, Family]                      No homepage
# 3519       0                  [Comedy]                      No homepage
# 3992       0                        []                      No homepage
# ...      ...                       ...                              ...
# 4210       0                 [Romance]                      No homepage
# 4694       0                   [Drama]                      No homepage
# 4657       0                        []                      No homepage
# 4660       0             [Documentary]  http://www.give-me-shelter.com/
# 4500       0       [Thriller, Mystery]                      No homepage
#
#           id                                           keywords  \
# ...

# %%
### Rearange the dataframe based on runtime column values ###
movies.sort_values(by="runtime", ascending=False, inplace=True)

# %%
### Find the top 5 successful years for the USA cinema based on the total income devided by number of movies  ###
movies["success"] = movies["revenue"] / movies["title"].count()
movies
movies.sort_values(by="success", ascending=False, inplace=False).head()
# Out:
#        budget                                         genres  \
# 0   237000000   [Action, Adventure, Fantasy, ScienceFiction]
# 25  200000000                     [Drama, Romance, Thriller]
# 16  220000000            [ScienceFiction, Action, Adventure]
# 28  150000000  [Action, Adventure, ScienceFiction, Thriller]
# 44  190000000                                       [Action]
#
#                              homepage      id  \
# 0         http://www.avatarmovie.com/   19995
# 25        http://www.titanicmovie.com     597
# 16  http://marvel.com/avengers_movie/   24428
# 28      http://www.jurassicworld.com/  135397
# 44           http://www.furious7.com/  168259
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 25  [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 16  [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# ...
